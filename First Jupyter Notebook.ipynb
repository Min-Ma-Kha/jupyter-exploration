# %% [markdown]
# # My First Markdown Cell

# %%
name = input("Enter your name: ")
print(f"---")
print(f"Hello, {name}!")
print(f"You are successfully running Python in a Jupyter Notebook! 🚀")
print(f"---")
# Out:
# Enter your name:  Min Ma Kha
# ---
# Hello, Min Ma Kha!
# You are successfully running Python in a Jupyter Notebook! 🚀
# ---
